# %% [markdown]
# # Embedding Ender's Game

# %% [markdown]
# In this notebook I will upload some books from the Ender's game universe, process them using *nltk*, and embed the words in the corpus using *word2vec*.
#
# This is inspired by [this video](https://youtu.be/pY9EwZ02sXU) and implemented using [this source code](https://github.com/llSourcell/word_vectors_game_of_thrones-LIVE).
#
# **Thank you Siraj Raval!**

# %%
#future is the missing compatibility layer between Python 2 and Python 3. 
#It allows you to use a single, clean Python 3.x-compatible codebase to 
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function

# %% [markdown]
# ## Some dependencies

# %%
#encoding. word encodig
import codecs
#finds all pathnames matching a pattern, like regex
import glob
#log events for libraries
import logging
#concurrency
import multiprocessing
#dealing with operating system , like reading file
import os
#pretty print, human readable
import pprint
#regular expressions
import re
import tensorflow as tf

# %%
#natural language toolkit
import nltk
#dimensionality reduction
import sklearn.manifold
from bhtsne import tsne
#math
import numpy as np
#plotting
import matplotlib.pyplot as plt
#parse dataset
import pandas as pd
#visualization
import seaborn as sns
#word 2 vec
from gensim.models import word2vec as w2v
# Out:
# C:\Users\Rey\Anaconda3\envs\tensorflow\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Preprocess using *nltk*

# %%
#stopwords like the at a an, unnecesasry
#tokenization into sentences, punkt 
#http://www.nltk.org/
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Rey\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Rey\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#initialize rawunicode , all text goes here
corpus_raw = u""
with codecs.open('Ender.txt', "r", "utf-8") as book_file:
        corpus_raw += book_file.read()

# %%
corpus_raw[0:10]
# Out:
# " ENDER'S G"

# %%
#tokenizastion! saved the trained model here
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
#tokenize into sentences
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
raw_sentences[0:10]
# Out:
# [' ENDER\'S GAME\r\n by Orson Scott Card\r\n Chapter 1 -- Third\r\n\r\n "I\'ve watched through his eyes, I\'ve listened through his ears, and tell you he\'s the one.',
#  'Or at least as close as we\'re going to get."',
#  '"That\'s what you said about the brother."',
#  '"The brother tested out impossible.',
#  'For other reasons.',
#  'Nothing to do with his ability."',
#  '"Same with the sister.',
#  'And there are doubts about him.',
#  "He's too malleable.",
#  'Too willing\r\nto submerge himself in someone else\'s will."']

# %%
#convert into list of words
#remove unecessary characters, split into words, no hyhens and shit
#split into words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#for each sentece, sentences where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
sentences[0:10]
# Out:
# [['ENDER',
#   'S',
#   'GAME',
#   'by',
#   'Orson',
#   'Scott',
#   'Card',
#   'Chapter',
#   'Third',
#   'I',
#   've',
#   'watched',
#   'through',
#   'his',
#   'eyes',
#   'I',
#   've',
#   'listened',
#   'through',
#   'his',
#   'ears',
#   'and',
#   'tell',
#   'you',
#   'he',
#   's',
#   'the',
#   'one'],
#  ['Or', 'at', 'least', 'as', 'close', 'as', 'we', 're', 'going', 'to', 'get'],
#  ['That', 's', 'what', 'you', 'said', 'about', 'the', 'brother'],
#  ['The', 'brother', 'tested', 'out', 'impossible'],
#  ['For', 'other', 'reasons'],
#  ['Nothing', 'to', 'do', 'with', 'his', 'ability'],
#  ['Same', 'with', 'the', 'sister'],
#  ['And', 'there', 'are', 'doubts', 'about', 'him'],
#  ['He', 's', 'too', 'malleable'],
#  ['Too',
#   'willing',
#   'to',
#   'submerge',
#   'himself',
#   'in',
#   'someone',
#   'else',
#   's',
#   'will']]

# %%
#print an example
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Nothing to do with his ability."
# ['Nothing', 'to', 'do', 'with', 'his', 'ability']

# %%
#count tokens, each one being a sentence
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 503,902 tokens

# %% [markdown]
# ## Build our model

# %%
#step 2 build our model, another one is Glove
#define hyperparameters

# Dimensionality of the resulting word vectors.
#more dimensions mean more traiig them, but more generalized
num_features = 300

#
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#rate 0 and 1e-5 
#how often to use
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
seed = 1

# %%
ender2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
ender2vec.build_vocab(sentences)
# Out:
# 2017-06-18 11:35:40,969 : INFO : collecting all words and their counts
# 2017-06-18 11:35:40,971 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-06-18 11:35:41,001 : INFO : PROGRESS: at sentence #10000, processed 111908 words, keeping 8059 word types
# 2017-06-18 11:35:41,038 : INFO : PROGRESS: at sentence #20000, processed 228097 words, keeping 11485 word types
# 2017-06-18 11:35:41,067 : INFO : PROGRESS: at sentence #30000, processed 353550 words, keeping 14782 word types
# 2017-06-18 11:35:41,092 : INFO : PROGRESS: at sentence #40000, processed 478152 words, keeping 17718 word types
# 2017-06-18 11:35:41,101 : INFO : collected 18299 word types from a corpus of 503902 raw words and 42110 sentences
# 2017-06-18 11:35:41,102 : INFO : Loading a fresh vocabulary
# 2017-06-18 11:35:41,133 : INFO : min_count=3 retains 7725 unique words (42% of original 18299, drops 10574)
# 2017-06-18 11:35:41,134 : INFO : min_count=3 leaves 490596 word corpus (97% of original 503902, drops 13306)
# 2017-06-18 11:35:41,165 : INFO : deleting the raw counts dictionary of 18299 items
# 2017-06-18 11:35:41,167 : INFO : sample=0.001 downsamples 66 most-common words
# 2017-06-18 11:35:41,169 : INFO : downsampling leaves estimated 369461 word corpus (75.3% of prior 490596)
# 2017-06-18 11:35:41,171 : INFO : estimated required memory for 7725 words and 300 dimensions: 22402500 bytes
# 2017-06-18 11:35:41,206 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(ender2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 7725

# %%
#train model on sentneces
ender2vec.train(sentences, 
        total_examples=ender2vec.corpus_count, epochs=5)
# Out:
# 2017-06-18 11:36:15,526 : INFO : training model with 4 workers on 7725 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-06-18 11:36:16,564 : INFO : PROGRESS: at 16.01% examples, 286955 words/s, in_qsize 7, out_qsize 0
# 2017-06-18 11:36:17,599 : INFO : PROGRESS: at 32.42% examples, 288546 words/s, in_qsize 8, out_qsize 0
# 2017-06-18 11:36:18,614 : INFO : PROGRESS: at 49.57% examples, 295477 words/s, in_qsize 7, out_qsize 0
# 2017-06-18 11:36:19,626 : INFO : PROGRESS: at 65.70% examples, 295764 words/s, in_qsize 7, out_qsize 0
# 2017-06-18 11:36:20,658 : INFO : PROGRESS: at 82.37% examples, 296183 words/s, in_qsize 7, out_qsize 0
# 2017-06-18 11:36:21,673 : INFO : PROGRESS: at 98.35% examples, 296189 words/s, in_qsize 5, out_qsize 0
# 2017-06-18 11:36:21,727 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-06-18 11:36:21,746 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-06-18 11:36:21,754 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-06-18 11:36:21,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-06-18 11:36:21,779 : INFO : training on 2519510 raw words (1846681 effective words) took 6.2s, 296021 effective words/s
# 1846681

# %% [markdown]
# ## That's it! we embedded our word vectors!
#
# ### Now Let's play...

# %%
#save model
#  if not os.path.exists("trained"): os.makedirs("trained")
# ender2vec.save(os.path.join("trained", "ender2vec.w2v"))

# %%
#load model
#ender2vec = w2v.Word2Vec.load(os.path.join("trained", "ender2vec.w2v"))

# %% [markdown]
# ### Perform dimentionality reduction using *tsne*

# %%
#put it all into a giant matrix
all_word_vectors_matrix = ender2vec.wv.syn0
#train t sne
all_word_vectors_matrix_2d = tsne(all_word_vectors_matrix.astype(
        'float64'))



#squash dimensionality to 2
#https://www.oreilly.com/learning/an-illustrated-introduction-to-the-t-sne-algorithm
#tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
#plot point in 2d space
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[ender2vec.wv.vocab[word].index])
            for word in ender2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#             word          x          y
# 0           Both  -1.574043  15.742758
# 1           took  19.287873  22.713574
# 2           lamp   8.164173  22.023539
# 3  investigation -27.488484   2.470459
# 4        grossly -26.542335  -0.708663
# 5          style  12.744257 -18.574075
# 6           pine  10.968159  19.502890
# 7     imprisoned -11.747718  -2.672585
# 8            box  -8.732950  13.891105
# 9         submit   1.172723 -15.057714

# %%
#plot
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(8, 6))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# ### Let's have a closer look at some interesting regions

# %%
plot_region(x_bounds=(22.0, 25.0), y_bounds=(12.0, 16.0))

# %%
plot_region(x_bounds=(6.0,9.0), y_bounds=(-16.0, -12.0))

# %% [markdown]
# ### Let's try some synonyms

# %%
ender2vec.most_similar("Bean")
# Out:
# 2017-06-18 11:39:56,115 : INFO : precomputing L2-norms of word weight vectors
# [('Abra', 0.8609213829040527),
#  ('Alai', 0.8308221697807312),
#  ('Bernard', 0.8178943991661072),
#  ('Petra', 0.8166934251785278),
#  ('Po', 0.808731198310852),
#  ('Suriyawong', 0.8062033653259277),
#  ('Sel', 0.8046296238899231),
#  ('Virlomi', 0.8032170534133911),
#  ('Ix', 0.8029365539550781),
#  ('Dorabella', 0.8027281761169434)]

# %%
ender2vec.most_similar("battleroom")
# Out:
# [('simulator', 0.9164535999298096),
#  ('building', 0.914559006690979),
#  ('corridors', 0.9068731069564819),
#  ('station', 0.9022289514541626),
#  ('gym', 0.900652289390564),
#  ('bathroom', 0.898011326789856),
#  ('entrance', 0.8955786228179932),
#  ('bridge', 0.8954177498817444),
#  ('tower', 0.8947381973266602),
#  ('mess', 0.8942477703094482)]

# %%
ender2vec.most_similar("Buggers")
# Out:
# [('buggers', 0.9320821762084961),
#  ('humans', 0.880068838596344),
#  ('Formics', 0.8708615303039551),
#  ('formics', 0.8585416078567505),
#  ('universe', 0.8513524532318115),
#  ('Russians', 0.8471916317939758),
#  ('First', 0.846630334854126),
#  ('rules', 0.8454385995864868),
#  ('Bugger', 0.8423735499382019),
#  ('situation', 0.8417836427688599)]

# %% [markdown]
# ### Let's look at some word associations

# %%
#distance, similarity, and ranking
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = ender2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Ender", "Valentine", "Bean")
# interesting: http://enderverse.wikia.com/wiki/Suriyawong
# Out:
# Ender is related to Valentine, as Abra is related to Bean
# 'Abra'

# %%
nearest_similarity_cosmul("Peter", "Valentine", "Locke")
# amazing!!
# Out:
# Peter is related to Valentine, as Hegemon is related to Locke
# 'Hegemon'

# %%
nearest_similarity_cosmul("run", "slow", "fight")
# Out:
# run is related to slow, as survive is related to fight
# 'survive'

# %%
nearest_similarity_cosmul("love", "hate", "formics")
# Out:
# love is related to hate, as adults is related to formics
# 'adults'
